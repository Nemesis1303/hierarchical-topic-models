# %%
import sys
sys.path.append('../')

import json
import multiprocessing as mp
import pathlib
import sys
import time
from subprocess import check_output
import warnings
import scipy.sparse as sparse
import random
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', None)

with warnings.catch_warnings():
    warnings.filterwarnings("ignore", category=DeprecationWarning)
    warnings.filterwarnings("ignore", category=FutureWarning)
from src.topicmodeling.manageModels import TMmodel

# %% [markdown]
# **Training parameters**

# %%
ntopics = 5
dropout = 0.1
epochs = 1
training_params = {
    "activation": "softplus",
    "batch_size": 64,
    "dropout": dropout,
    "hidden_sizes": (50, 50),
    "labels": "",
    "learn_priors": True,
    "lr": 2e-3,
    "momentum": 0.99,
    "num_data_loader_workers": mp.cpu_count(),
    "num_threads": 4,
    "optimize_interval": 10,
    "reduce_on_plateau": False,
    "sbert_model_to_load": "paraphrase-distilroberta-base-v1",
    "solver": "adam",
    "thetas_thr": 0.003,
    "topic_prior_mean": 0.0,
    "topic_prior_variance": None,
    "ctm_model_type": "CombinedTM",
    "model_type": "prodLDA",
    "ntopics": ntopics,
    "num_epochs": epochs,
    "num_samples": 20
}

# %%
def get_model_config(TMparam,
                     hierarchy_level,
                     htm_version,
                     expansion_tpc,
                     thr):
    
    fields = ["ntopics",
              "thetas_thr",
              "labels",
              "model_type",
              "ctm_model_type",
              "hidden_sizes",
              "activation",
              "dropout",
              "learn_priors",
              "lr",
              "momentum",
              "solver",
              "num_epochs",
              "reduce_on_plateau",
              "batch_size",
              "topic_prior_mean",
              "topic_prior_variance",
              "num_samples",
              "num_data_loader_workers"]

    params = {"trainer": "ctm",
              "TMparam": {t: TMparam[t] for t in fields},
              "hierarchy-level": hierarchy_level,
              "htm-version": htm_version,
              "expansion_tpc": expansion_tpc,
              "thr": thr}

    return params

# %% [markdown]
# **Training**

# %%
def train_automatic(path_corpus: str, path_script:str):

    # Get training corpus (already preprocessed)
    corpusFile = pathlib.Path(path_corpus)
    print(corpusFile)
    if not corpusFile.is_dir() and not corpusFile.is_file:
        sys.exit(
            "The provided corpus file does not exist.")

    # Train root model
    train_config = get_model_config(
        TMparam=training_params,
        hierarchy_level=0,
        htm_version=None,
        expansion_tpc=None,
        thr=None)

    configFile = corpusFile.parent.joinpath("trainconfig.json")
    if configFile.is_file():
        with configFile.open('r', encoding='utf8') as fin:
            train_config_txt = json.load(fin)
            train_config_txt["TMparam"] = train_config["TMparam"]
        with configFile.open("w", encoding="utf-8") as fout:
            json.dump(train_config_txt, fout, ensure_ascii=False,
                      indent=2, default=str)

    t_start = time.perf_counter()
    cmd = f'python {path_script}/src/topicmodeling/topicmodeling.py --train --config {configFile.as_posix()}'
    print(cmd)

    print(f'-- -- Running command {cmd}')
    output = check_output(args=cmd, shell=True)
    t_end = time.perf_counter()

    t_total = t_end - t_start
    print(f"Total training time root model --> {t_total}")

# %%
train_automatic(path_corpus="/Users/lbartolome/Documents/GitHub/UserInLoopHTM/data/CORDIS/corpus.parquet", path_script="/Users/lbartolome/Documents/GitHub/UserInLoopHTM")
# Out:
# /Users/lbartolome/Documents/GitHub/UserInLoopHTM/data/CORDIS/corpus.parquet
# python /Users/lbartolome/Documents/GitHub/UserInLoopHTM/src/topicmodeling/topicmodeling.py --train --config /Users/lbartolome/Documents/GitHub/UserInLoopHTM/data/CORDIS/trainconfig.json
# -- -- Running command python /Users/lbartolome/Documents/GitHub/UserInLoopHTM/src/topicmodeling/topicmodeling.py --train --config /Users/lbartolome/Documents/GitHub/UserInLoopHTM/data/CORDIS/trainconfig.json
# INFO:textPreproc:-- -- Saving lemmas and embeddings in auxiliary files
# INFO:textPreproc:ddf read, starting compute
# Epoch: [1/1]	 Seen Samples: [45824/45837]	Train Loss: 950.9997712886533	Valid Loss: 934.5803317542837	Time: 0:01:03.262346: : 1it [02:50, 107.72s/it]/Users/lbartolome/Documents/GitHub/UserInLoopHTM/src/topicmodeling/models/neural_models/contextualized_topic_models/ctm_network/ctm.py:653: Warning: This is an experimental feature that we has not been fully tested. Refer to the following issue:https://github.com/MilaNLProc/contextualized-topic-models/issues/38
#   warnings.warn(
# Epoch: [1/1]	 Seen Samples: [45824/45837]	Train Loss: 950.9997712886533	Time: 0:01:03.262346: : 1it [02:50, 170.98s/it]
# 100%|██████████| 717/717 [01:09<00:00, 10.38it/s]
# 100%|██████████| 717/717 [01:08<00:00, 10.47it/s]
# INFO:TMmodel:-- -- -- Topic model object (TMmodel) successfully created
# INFO:gensim.corpora.dictionary:adding document #0 to Dictionary<0 unique tokens: []>
# INFO:gensim.corpora.dictionary:adding document #10000 to Dictionary<19604 unique tokens: ['argument', 'british', 'career', 'cease', 'change']...>
# INFO:gensim.corpora.dictionary:adding document #20000 to Dictionary<19880 unique tokens: ['argument', 'british', 'career', 'cease', 'change']...>
# INFO:gensim.corpora.dictionary:adding document #30000 to Dictionary<19884 unique tokens: ['argument', 'british', 'career', 'cease', 'change']...>
# INFO:gensim.corpora.dictionary:adding document #40000 to Dictionary<19884 unique tokens: ['argument', 'british', 'career', 'cease', 'change']...>
# INFO:gensim.corpora.dictionary:built Dictionary<19884 unique tokens: ['argument', 'british', 'career', 'cease', 'change']...> from 45837 documents (total 4498242 corpus positions)
# INFO:gensim.utils:Dictionary lifecycle event {'msg': "built Dictionary<19884 unique tokens: ['argument', 'british', 'career', 'cease', 'change']...> from 45837 documents (total 4498242 corpus positions)", 'datetime': '2023-05-10T12:58:47.779624', 'gensim': '4.3.1', 'python': '3.8.16 (default, Dec  7 2022, 01:27:54) \n[Clang 14.0.0 (clang-1400.0.29.202)]', 'platform': 'macOS-13.3.1-arm64-arm-64bit', 'event': 'created'}
# INFO:TMmodel:Calculating coherence c_v.
# INFO:gensim.topic_coherence.probability_estimation:using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:7 accumulators retrieved from output queue
# INFO:gensim.topic_coherence.text_analysis:accumulated word occurrence stats for 163145 virtual documents
# INFO:TMmodel:[0.6242889979163306, 0.7640702606368759, 0.505968138424412, 0.4627337588833527, 0.5705773780236945]
# INFO:TMmodel:Calculating coherence c_npmi.
# INFO:gensim.topic_coherence.probability_estimation:using ParallelWordOccurrenceAccumulator<processes=7, batch_size=64> to estimate probabilities from sliding windows
# INFO:gensim.topic_coherence.text_analysis:1 batches submitted to accumulate stats from 64 documents (5668 virtual)
# INFO:gensim.topic_coherence.text_analysis:2 batches submitted to accumulate stats from 128 documents (11287 virtual)
# INFO:gensim.topic_coherence.text_analysis:3 batches submitted to accumulate stats from 192 documents (16939 virtual)
# INFO:gensim.topic_coherence.text_analysis:4 batches submitted to accumulate stats from 256 documents (22653 virtual)
# INFO:gensim.topic_coherence.text_analysis:5 batches submitted to accumulate stats from 320 documents (28493 virtual)
# INFO:gensim.topic_coherence.text_analysis:6 batches submitted to accumulate stats from 384 documents (33839 virtual)
# INFO:gensim.topic_coherence.text_analysis:7 batches submitted to accumulate stats from 448 documents (39474 virtual)
# INFO:gensim.topic_coherence.text_analysis:8 batches submitted to accumulate stats from 512 documents (45253 virtual)
# INFO:gensim.topic_coherence.text_analysis:9 batches submitted to accumulate stats from 576 documents (51026 virtual)
# INFO:gensim.topic_coherence.text_analysis:10 batches submitted to accumulate stats from 640 documents (56755 virtual)
# INFO:gensim.topic_coherence.text_analysis:11 batches submitted to accumulate stats from 704 documents (62723 virtual)
# INFO:gensim.topic_coherence.text_analysis:12 batches submitted to accumulate stats from 768 documents (68531 virtual)
# INFO:gensim.topic_coherence.text_analysis:13 batches submitted to accumulate stats from 832 documents (74250 virtual)
# INFO:gensim.topic_coherence.text_analysis:14 batches submitted to accumulate stats from 896 documents (80107 virtual)
# INFO:gensim.topic_coherence.text_analysis:15 batches submitted to accumulate stats from 960 documents (85727 virtual)
# INFO:gensim.topic_coherence.text_analysis:16 batches submitted to accumulate stats from 1024 documents (91438 virtual)
# INFO:gensim.topic_coherence.text_analysis:17 batches submitted to accumulate stats from 1088 documents (97178 virtual)
# INFO:gensim.topic_coherence.text_analysis:18 batches submitted to accumulate stats from 1152 documents (102838 virtual)
# INFO:gensim.topic_coherence.text_analysis:19 batches submitted to accumulate stats from 1216 documents (108552 virtual)
# INFO:gensim.topic_coherence.text_analysis:20 batches submitted to accumulate stats from 1280 documents (114212 virtual)
# INFO:gensim.topic_coherence.text_analysis:21 batches submitted to accumulate stats from 1344 documents (119986 virtual)
# INFO:gensim.topic_coherence.text_analysis:22 batches submitted to accumulate stats from 1408 documents (125905 virtual)
# INFO:gensim.topic_coherence.text_analysis:23 batches submitted to accumulate stats from 1472 documents (131663 virtual)
# INFO:gensim.topic_coherence.text_analysis:24 batches submitted to accumulate stats from 1536 documents (137486 virtual)
# INFO:gensim.topic_coherence.text_analysis:25 batches submitted to accumulate stats from 1600 documents (143224 virtual)
# INFO:gensim.topic_coherence.text_analysis:26 batches submitted to accumulate stats from 1664 documents (148782 virtual)
# INFO:gensim.topic_coherence.text_analysis:27 batches submitted to accumulate stats from 1728 documents (154650 virtual)
# INFO:gensim.topic_coherence.text_analysis:28 batches submitted to accumulate stats from 1792 documents (160271 virtual)
# INFO:gensim.topic_coherence.text_analysis:29 batches submitted to accumulate stats from 1856 documents (166075 virtual)
# INFO:gensim.topic_coherence.text_analysis:30 batches submitted to accumulate stats from 1920 documents (171990 virtual)
# INFO:gensim.topic_coherence.text_analysis:31 batches submitted to accumulate stats from 1984 documents (177523 virtual)
# INFO:gensim.topic_coherence.text_analysis:32 batches submitted to accumulate stats from 2048 documents (183366 virtual)
# INFO:gensim.topic_coherence.text_analysis:33 batches submitted to accumulate stats from 2112 documents (188849 virtual)
# INFO:gensim.topic_coherence.text_analysis:34 batches submitted to accumulate stats from 2176 documents (194666 virtual)
# INFO:gensim.topic_coherence.text_analysis:35 batches submitted to accumulate stats from 2240 documents (200267 virtual)
# INFO:gensim.topic_coherence.text_analysis:36 batches submitted to accumulate stats from 2304 documents (205854 virtual)
# INFO:gensim.topic_coherence.text_analysis:37 batches submitted to accumulate stats from 2368 documents (211512 virtual)
# INFO:gensim.topic_coherence.text_analysis:38 batches submitted to accumulate stats from 2432 documents (216863 virtual)
# INFO:gensim.topic_coherence.text_analysis:39 batches submitted to accumulate stats from 2496 documents (222537 virtual)
# INFO:gensim.topic_coherence.text_analysis:40 batches submitted to accumulate stats from 2560 documents (228189 virtual)
# INFO:gensim.topic_coherence.text_analysis:41 batches submitted to accumulate stats from 2624 documents (234040 virtual)
# INFO:gensim.topic_coherence.text_analysis:42 batches submitted to accumulate stats from 2688 documents (240103 virtual)
# INFO:gensim.topic_coherence.text_analysis:43 batches submitted to accumulate stats from 2752 documents (245893 virtual)
# INFO:gensim.topic_coherence.text_analysis:44 batches submitted to accumulate stats from 2816 documents (251543 virtual)
# INFO:gensim.topic_coherence.text_analysis:45 batches submitted to accumulate stats from 2880 documents (257271 virtual)
# INFO:gensim.topic_coherence.text_analysis:46 batches submitted to accumulate stats from 2944 documents (263018 virtual)
# INFO:gensim.topic_coherence.text_analysis:47 batches submitted to accumulate stats from 3008 documents (268818 virtual)
# INFO:gensim.topic_coherence.text_analysis:48 batches submitted to accumulate stats from 3072 documents (274399 virtual)
# INFO:gensim.topic_coherence.text_analysis:49 batches submitted to accumulate stats from 3136 documents (280003 virtual)
# INFO:gensim.topic_coherence.text_analysis:50 batches submitted to accumulate stats from 3200 documents (285625 virtual)
# INFO:gensim.topic_coherence.text_analysis:51 batches submitted to accumulate stats from 3264 documents (291164 virtual)
# INFO:gensim.topic_coherence.text_analysis:52 batches submitted to accumulate stats from 3328 documents (296608 virtual)
# INFO:gensim.topic_coherence.text_analysis:53 batches submitted to accumulate stats from 3392 documents (302428 virtual)
# INFO:gensim.topic_coherence.text_analysis:54 batches submitted to accumulate stats from 3456 documents (308062 virtual)
# INFO:gensim.topic_coherence.text_analysis:55 batches submitted to accumulate stats from 3520 documents (313808 virtual)
# INFO:gensim.topic_coherence.text_analysis:56 batches submitted to accumulate stats from 3584 documents (319712 virtual)
# INFO:gensim.topic_coherence.text_analysis:57 batches submitted to accumulate stats from 3648 documents (325272 virtual)
# INFO:gensim.topic_coherence.text_analysis:58 batches submitted to accumulate stats from 3712 documents (331158 virtual)
# INFO:gensim.topic_coherence.text_analysis:59 batches submitted to accumulate stats from 3776 documents (336747 virtual)
# INFO:gensim.topic_coherence.text_analysis:60 batches submitted to accumulate stats from 3840 documents (342554 virtual)
# INFO:gensim.topic_coherence.text_analysis:61 batches submitted to accumulate stats from 3904 documents (348229 virtual)
# INFO:gensim.topic_coherence.text_analysis:62 batches submitted to accumulate stats from 3968 documents (353971 virtual)
# INFO:gensim.topic_coherence.text_analysis:63 batches submitted to accumulate stats from 4032 documents (359816 virtual)
# INFO:gensim.topic_coherence.text_analysis:64 batches submitted to accumulate stats from 4096 documents (365376 virtual)
# INFO:gensim.topic_coherence.text_analysis:65 batches submitted to accumulate stats from 4160 documents (371141 virtual)
# INFO:gensim.topic_coherence.text_analysis:66 batches submitted to accumulate stats from 4224 documents (377232 virtual)
# INFO:gensim.topic_coherence.text_analysis:67 batches submitted to accumulate stats from 4288 documents (382719 virtual)
# INFO:gensim.topic_coherence.text_analysis:68 batches submitted to accumulate stats from 4352 documents (388438 virtual)
# INFO:gensim.topic_coherence.text_analysis:69 batches submitted to accumulate stats from 4416 documents (394297 virtual)
# INFO:gensim.topic_coherence.text_analysis:70 batches submitted to accumulate stats from 4480 documents (400262 virtual)
# INFO:gensim.topic_coherence.text_analysis:71 batches submitted to accumulate stats from 4544 documents (405835 virtual)
# INFO:gensim.topic_coherence.text_analysis:72 batches submitted to accumulate stats from 4608 documents (411529 virtual)
# INFO:gensim.topic_coherence.text_analysis:73 batches submitted to accumulate stats from 4672 documents (416985 virtual)
# INFO:gensim.topic_coherence.text_analysis:74 batches submitted to accumulate stats from 4736 documents (422512 virtual)
# INFO:gensim.topic_coherence.text_analysis:75 batches submitted to accumulate stats from 4800 documents (427718 virtual)
# INFO:gensim.topic_coherence.text_analysis:76 batches submitted to accumulate stats from 4864 documents (433675 virtual)
# INFO:gensim.topic_coherence.text_analysis:77 batches submitted to accumulate stats from 4928 documents (439218 virtual)
# INFO:gensim.topic_coherence.text_analysis:78 batches submitted to accumulate stats from 4992 documents (445035 virtual)
# INFO:gensim.topic_coherence.text_analysis:79 batches submitted to accumulate stats from 5056 documents (450767 virtual)
# INFO:gensim.topic_coherence.text_analysis:80 batches submitted to accumulate stats from 5120 documents (456840 virtual)
# INFO:gensim.topic_coherence.text_analysis:81 batches submitted to accumulate stats from 5184 documents (462546 virtual)
# INFO:gensim.topic_coherence.text_analysis:82 batches submitted to accumulate stats from 5248 documents (468366 virtual)
# INFO:gensim.topic_coherence.text_analysis:83 batches submitted to accumulate stats from 5312 documents (473891 virtual)
# INFO:gensim.topic_coherence.text_analysis:84 batches submitted to accumulate stats from 5376 documents (479641 virtual)
# INFO:gensim.topic_coherence.text_analysis:85 batches submitted to accumulate stats from 5440 documents (485304 virtual)
# INFO:gensim.topic_coherence.text_analysis:86 batches submitted to accumulate stats from 5504 documents (490765 virtual)
# INFO:gensim.topic_coherence.text_analysis:87 batches submitted to accumulate stats from 5568 documents (496232 virtual)
# INFO:gensim.topic_coherence.text_analysis:88 batches submitted to accumulate stats from 5632 documents (501856 virtual)
# INFO:gensim.topic_coherence.text_analysis:89 batches submitted to accumulate stats from 5696 documents (507534 virtual)
# INFO:gensim.topic_coherence.text_analysis:90 batches submitted to accumulate stats from 5760 documents (512917 virtual)
# INFO:gensim.topic_coherence.text_analysis:91 batches submitted to accumulate stats from 5824 documents (518430 virtual)
# INFO:gensim.topic_coherence.text_analysis:92 batches submitted to accumulate stats from 5888 documents (524258 virtual)
# INFO:gensim.topic_coherence.text_analysis:93 batches submitted to accumulate stats from 5952 documents (529986 virtual)
# INFO:gensim.topic_coherence.text_analysis:94 batches submitted to accumulate stats from 6016 documents (535802 virtual)
# INFO:gensim.topic_coherence.text_analysis:95 batches submitted to accumulate stats from 6080 documents (541927 virtual)
# INFO:gensim.topic_coherence.text_analysis:96 batches submitted to accumulate stats from 6144 documents (547631 virtual)
# INFO:gensim.topic_coherence.text_analysis:97 batches submitted to accumulate stats from 6208 documents (553093 virtual)
# INFO:gensim.topic_coherence.text_analysis:98 batches submitted to accumulate stats from 6272 documents (558978 virtual)
# INFO:gensim.topic_coherence.text_analysis:99 batches submitted to accumulate stats from 6336 documents (564594 virtual)
# INFO:gensim.topic_coherence.text_analysis:100 batches submitted to accumulate stats from 6400 documents (570332 virtual)
# INFO:gensim.topic_coherence.text_analysis:101 batches submitted to accumulate stats from 6464 documents (576091 virtual)
# INFO:gensim.topic_coherence.text_analysis:102 batches submitted to accumulate stats from 6528 documents (581423 virtual)
# INFO:gensim.topic_coherence.text_analysis:103 batches submitted to accumulate stats from 6592 documents (586849 virtual)
# INFO:gensim.topic_coherence.text_analysis:104 batches submitted to accumulate stats from 6656 documents (592467 virtual)
# INFO:gensim.topic_coherence.text_analysis:105 batches submitted to accumulate stats from 6720 documents (597792 virtual)
# INFO:gensim.topic_coherence.text_analysis:106 batches submitted to accumulate stats from 6784 documents (603264 virtual)
# INFO:gensim.topic_coherence.text_analysis:107 batches submitted to accumulate stats from 6848 documents (609072 virtual)
# INFO:gensim.topic_coherence.text_analysis:108 batches submitted to accumulate stats from 6912 documents (614770 virtual)
# INFO:gensim.topic_coherence.text_analysis:109 batches submitted to accumulate stats from 6976 documents (620452 virtual)
# INFO:gensim.topic_coherence.text_analysis:110 batches submitted to accumulate stats from 7040 documents (625864 virtual)
# INFO:gensim.topic_coherence.text_analysis:111 batches submitted to accumulate stats from 7104 documents (631509 virtual)
# INFO:gensim.topic_coherence.text_analysis:112 batches submitted to accumulate stats from 7168 documents (637360 virtual)
# INFO:gensim.topic_coherence.text_analysis:113 batches submitted to accumulate stats from 7232 documents (643272 virtual)
# INFO:gensim.topic_coherence.text_analysis:114 batches submitted to accumulate stats from 7296 documents (649230 virtual)
# INFO:gensim.topic_coherence.text_analysis:115 batches submitted to accumulate stats from 7360 documents (654969 virtual)
# INFO:gensim.topic_coherence.text_analysis:116 batches submitted to accumulate stats from 7424 documents (660618 virtual)
# INFO:gensim.topic_coherence.text_analysis:117 batches submitted to accumulate stats from 7488 documents (666653 virtual)
# INFO:gensim.topic_coherence.text_analysis:118 batches submitted to accumulate stats from 7552 documents (672818 virtual)
# INFO:gensim.topic_coherence.text_analysis:119 batches submitted to accumulate stats from 7616 documents (678343 virtual)
# INFO:gensim.topic_coherence.text_analysis:120 batches submitted to accumulate stats from 7680 documents (684198 virtual)
# INFO:gensim.topic_coherence.text_analysis:121 batches submitted to accumulate stats from 7744 documents (690144 virtual)
# INFO:gensim.topic_coherence.text_analysis:122 batches submitted to accumulate stats from 7808 documents (695975 virtual)
# INFO:gensim.topic_coherence.text_analysis:123 batches submitted to accumulate stats from 7872 documents (701904 virtual)
# INFO:gensim.topic_coherence.text_analysis:124 batches submitted to accumulate stats from 7936 documents (707568 virtual)
# INFO:gensim.topic_coherence.text_analysis:125 batches submitted to accumulate stats from 8000 documents (713368 virtual)
# INFO:gensim.topic_coherence.text_analysis:126 batches submitted to accumulate stats from 8064 documents (719030 virtual)
# INFO:gensim.topic_coherence.text_analysis:127 batches submitted to accumulate stats from 8128 documents (724993 virtual)
# INFO:gensim.topic_coherence.text_analysis:128 batches submitted to accumulate stats from 8192 documents (730821 virtual)
# INFO:gensim.topic_coherence.text_analysis:129 batches submitted to accumulate stats from 8256 documents (736677 virtual)
# INFO:gensim.topic_coherence.text_analysis:130 batches submitted to accumulate stats from 8320 documents (742374 virtual)
# INFO:gensim.topic_coherence.text_analysis:131 batches submitted to accumulate stats from 8384 documents (748161 virtual)
# INFO:gensim.topic_coherence.text_analysis:132 batches submitted to accumulate stats from 8448 documents (754190 virtual)
# INFO:gensim.topic_coherence.text_analysis:133 batches submitted to accumulate stats from 8512 documents (759900 virtual)
# INFO:gensim.topic_coherence.text_analysis:134 batches submitted to accumulate stats from 8576 documents (765567 virtual)
# INFO:gensim.topic_coherence.text_analysis:135 batches submitted to accumulate stats from 8640 documents (771466 virtual)
# INFO:gensim.topic_coherence.text_analysis:136 batches submitted to accumulate stats from 8704 documents (777122 virtual)
# INFO:gensim.topic_coherence.text_analysis:137 batches submitted to accumulate stats from 8768 documents (782803 virtual)
# INFO:gensim.topic_coherence.text_analysis:138 batches submitted to accumulate stats from 8832 documents (788374 virtual)
# INFO:gensim.topic_coherence.text_analysis:139 batches submitted to accumulate stats from 8896 documents (794178 virtual)
# INFO:gensim.topic_coherence.text_analysis:140 batches submitted to accumulate stats from 8960 documents (799979 virtual)
# INFO:gensim.topic_coherence.text_analysis:141 batches submitted to accumulate stats from 9024 documents (805954 virtual)
# INFO:gensim.topic_coherence.text_analysis:142 batches submitted to accumulate stats from 9088 documents (811553 virtual)
# INFO:gensim.topic_coherence.text_analysis:143 batches submitted to accumulate stats from 9152 documents (817398 virtual)
# INFO:gensim.topic_coherence.text_analysis:144 batches submitted to accumulate stats from 9216 documents (823497 virtual)
# INFO:gensim.topic_coherence.text_analysis:145 batches submitted to accumulate stats from 9280 documents (828947 virtual)
# INFO:gensim.topic_coherence.text_analysis:146 batches submitted to accumulate stats from 9344 documents (834310 virtual)
# INFO:gensim.topic_coherence.text_analysis:147 batches submitted to accumulate stats from 9408 documents (840063 virtual)
# INFO:gensim.topic_coherence.text_analysis:148 batches submitted to accumulate stats from 9472 documents (845687 virtual)
# INFO:gensim.topic_coherence.text_analysis:149 batches submitted to accumulate stats from 9536 documents (851250 virtual)
# INFO:gensim.topic_coherence.text_analysis:150 batches submitted to accumulate stats from 9600 documents (856798 virtual)
# INFO:gensim.topic_coherence.text_analysis:151 batches submitted to accumulate stats from 9664 documents (862577 virtual)
# INFO:gensim.topic_coherence.text_analysis:152 batches submitted to accumulate stats from 9728 documents (868302 virtual)
# INFO:gensim.topic_coherence.text_analysis:153 batches submitted to accumulate stats from 9792 documents (873735 virtual)
# INFO:gensim.topic_coherence.text_analysis:154 batches submitted to accumulate stats from 9856 documents (879406 virtual)
# INFO:gensim.topic_coherence.text_analysis:155 batches submitted to accumulate stats from 9920 documents (884815 virtual)
# INFO:gensim.topic_coherence.text_analysis:156 batches submitted to accumulate stats from 9984 documents (890937 virtual)
# INFO:gensim.topic_coherence.text_analysis:157 batches submitted to accumulate stats from 10048 documents (896627 virtual)
# INFO:gensim.topic_coherence.text_analysis:158 batches submitted to accumulate stats from 10112 documents (902438 virtual)
# INFO:gensim.topic_coherence.text_analysis:159 batches submitted to accumulate stats from 10176 documents (907885 virtual)
# INFO:gensim.topic_coherence.text_analysis:160 batches submitted to accumulate stats from 10240 documents (913756 virtual)
# INFO:gensim.topic_coherence.text_analysis:161 batches submitted to accumulate stats from 10304 documents (919699 virtual)
# INFO:gensim.topic_coherence.text_analysis:162 batches submitted to accumulate stats from 10368 documents (925470 virtual)
# INFO:gensim.topic_coherence.text_analysis:163 batches submitted to accumulate stats from 10432 documents (931473 virtual)
# INFO:gensim.topic_coherence.text_analysis:164 batches submitted to accumulate stats from 10496 documents (937223 virtual)
# INFO:gensim.topic_coherence.text_analysis:165 batches submitted to accumulate stats from 10560 documents (943096 virtual)
# INFO:gensim.topic_coherence.text_analysis:166 batches submitted to accumulate stats from 10624 documents (948930 virtual)
# INFO:gensim.topic_coherence.text_analysis:167 batches submitted to accumulate stats from 10688 documents (955039 virtual)
# INFO:gensim.topic_coherence.text_analysis:168 batches submitted to accumulate stats from 10752 documents (960486 virtual)
# INFO:gensim.topic_coherence.text_analysis:169 batches submitted to accumulate stats from 10816 documents (966253 virtual)
# INFO:gensim.topic_coherence.text_analysis:170 batches submitted to accumulate stats from 10880 documents (971624 virtual)
# INFO:gensim.topic_coherence.text_analysis:171 batches submitted to accumulate stats from 10944 documents (977486 virtual)
# INFO:gensim.topic_coherence.text_analysis:172 batches submitted to accumulate stats from 11008 documents (983207 virtual)
# INFO:gensim.topic_coherence.text_analysis:173 batches submitted to accumulate stats from 11072 documents (988782 virtual)
# INFO:gensim.topic_coherence.text_analysis:174 batches submitted to accumulate stats from 11136 documents (994533 virtual)
# INFO:gensim.topic_coherence.text_analysis:175 batches submitted to accumulate stats from 11200 documents (1000182 virtual)
# INFO:gensim.topic_coherence.text_analysis:176 batches submitted to accumulate stats from 11264 documents (1005676 virtual)
# INFO:gensim.topic_coherence.text_analysis:177 batches submitted to accumulate stats from 11328 documents (1011458 virtual)
# INFO:gensim.topic_coherence.text_analysis:178 batches submitted to accumulate stats from 11392 documents (1017296 virtual)
# INFO:gensim.topic_coherence.text_analysis:179 batches submitted to accumulate stats from 11456 documents (1022913 virtual)
# INFO:gensim.topic_coherence.text_analysis:180 batches submitted to accumulate stats from 11520 documents (1028657 virtual)
# INFO:gensim.topic_coherence.text_analysis:181 batches submitted to accumulate stats from 11584 documents (1034360 virtual)
# INFO:gensim.topic_coherence.text_analysis:182 batches submitted to accumulate stats from 11648 documents (1040211 virtual)
# INFO:gensim.topic_coherence.text_analysis:183 batches submitted to accumulate stats from 11712 documents (1045849 virtual)
# INFO:gensim.topic_coherence.text_analysis:184 batches submitted to accumulate stats from 11776 documents (1051549 virtual)
# INFO:gensim.topic_coherence.text_analysis:185 batches submitted to accumulate stats from 11840 documents (1057115 virtual)
# INFO:gensim.topic_coherence.text_analysis:186 batches submitted to accumulate stats from 11904 documents (1063051 virtual)
# INFO:gensim.topic_coherence.text_analysis:187 batches submitted to accumulate stats from 11968 documents (1068749 virtual)
# INFO:gensim.topic_coherence.text_analysis:188 batches submitted to accumulate stats from 12032 documents (1074403 virtual)
# INFO:gensim.topic_coherence.text_analysis:189 batches submitted to accumulate stats from 12096 documents (1079845 virtual)
# INFO:gensim.topic_coherence.text_analysis:190 batches submitted to accumulate stats from 12160 documents (1085527 virtual)
# INFO:gensim.topic_coherence.text_analysis:191 batches submitted to accumulate stats from 12224 documents (1091371 virtual)
# INFO:gensim.topic_coherence.text_analysis:192 batches submitted to accumulate stats from 12288 documents (1097030 virtual)
# INFO:gensim.topic_coherence.text_analysis:193 batches submitted to accumulate stats from 12352 documents (1102805 virtual)
# INFO:gensim.topic_coherence.text_analysis:194 batches submitted to accumulate stats from 12416 documents (1108591 virtual)
# INFO:gensim.topic_coherence.text_analysis:195 batches submitted to accumulate stats from 12480 documents (1114171 virtual)
# INFO:gensim.topic_coherence.text_analysis:196 batches submitted to accumulate stats from 12544 documents (1119680 virtual)
# INFO:gensim.topic_coherence.text_analysis:197 batches submitted to accumulate stats from 12608 documents (1125378 virtual)
# INFO:gensim.topic_coherence.text_analysis:198 batches submitted to accumulate stats from 12672 documents (1130902 virtual)
# INFO:gensim.topic_coherence.text_analysis:199 batches submitted to accumulate stats from 12736 documents (1136628 virtual)
# INFO:gensim.topic_coherence.text_analysis:200 batches submitted to accumulate stats from 12800 documents (1142159 virtual)
# INFO:gensim.topic_coherence.text_analysis:201 batches submitted to accumulate stats from 12864 documents (1147951 virtual)
# INFO:gensim.topic_coherence.text_analysis:202 batches submitted to accumulate stats from 12928 documents (1153760 virtual)
# INFO:gensim.topic_coherence.text_analysis:203 batches submitted to accumulate stats from 12992 documents (1159649 virtual)
# INFO:gensim.topic_coherence.text_analysis:204 batches submitted to accumulate stats from 13056 documents (1164889 virtual)
# INFO:gensim.topic_coherence.text_analysis:205 batches submitted to accumulate stats from 13120 documents (1170647 virtual)
# INFO:gensim.topic_coherence.text_analysis:206 batches submitted to accumulate stats from 13184 documents (1176151 virtual)
# INFO:gensim.topic_coherence.text_analysis:207 batches submitted to accumulate stats from 13248 documents (1181750 virtual)
# INFO:gensim.topic_coherence.text_analysis:208 batches submitted to accumulate stats from 13312 documents (1187374 virtual)
# INFO:gensim.topic_coherence.text_analysis:209 batches submitted to accumulate stats from 13376 documents (1192925 virtual)
# INFO:gensim.topic_coherence.text_analysis:210 batches submitted to accumulate stats from 13440 documents (1198607 virtual)
# INFO:gensim.topic_coherence.text_analysis:211 batches submitted to accumulate stats from 13504 documents (1204474 virtual)
# INFO:gensim.topic_coherence.text_analysis:212 batches submitted to accumulate stats from 13568 documents (1210069 virtual)
# INFO:gensim.topic_coherence.text_analysis:213 batches submitted to accumulate stats from 13632 documents (1215661 virtual)
# INFO:gensim.topic_coherence.text_analysis:214 batches submitted to accumulate stats from 13696 documents (1221616 virtual)
# INFO:gensim.topic_coherence.text_analysis:215 batches submitted to accumulate stats from 13760 documents (1227552 virtual)
# INFO:gensim.topic_coherence.text_analysis:216 batches submitted to accumulate stats from 13824 documents (1233318 virtual)
# INFO:gensim.topic_coherence.text_analysis:217 batches submitted to accumulate stats from 13888 documents (1239004 virtual)
# INFO:gensim.topic_coherence.text_analysis:218 batches submitted to accumulate stats from 13952 documents (1244899 virtual)
# INFO:gensim.topic_coherence.text_analysis:219 batches submitted to accumulate stats from 14016 documents (1250401 virtual)
# INFO:gensim.topic_coherence.text_analysis:220 batches submitted to accumulate stats from 14080 documents (1256141 virtual)
# INFO:gensim.topic_coherence.text_analysis:221 batches submitted to accumulate stats from 14144 documents (1261841 virtual)
# INFO:gensim.topic_coherence.text_analysis:222 batches submitted to accumulate stats from 14208 documents (1267636 virtual)
# INFO:gensim.topic_coherence.text_analysis:223 batches submitted to accumulate stats from 14272 documents (1273234 virtual)
# INFO:gensim.topic_coherence.text_analysis:224 batches submitted to accumulate stats from 14336 documents (1279116 virtual)
# INFO:gensim.topic_coherence.text_analysis:225 batches submitted to accumulate stats from 14400 documents (1284884 virtual)
# INFO:gensim.topic_coherence.text_analysis:226 batches submitted to accumulate stats from 14464 documents (1290822 virtual)
# INFO:gensim.topic_coherence.text_analysis:227 batches submitted to accumulate stats from 14528 documents (1296640 virtual)
# INFO:gensim.topic_coherence.text_analysis:228 batches submitted to accumulate stats from 14592 documents (1302387 virtual)
# INFO:gensim.topic_coherence.text_analysis:229 batches submitted to accumulate stats from 14656 documents (1308036 virtual)
# INFO:gensim.topic_coherence.text_analysis:230 batches submitted to accumulate stats from 14720 documents (1313660 virtual)
# INFO:gensim.topic_coherence.text_analysis:231 batches submitted to accumulate stats from 14784 documents (1319499 virtual)
# INFO:gensim.topic_coherence.text_analysis:232 batches submitted to accumulate stats from 14848 documents (1325405 virtual)
# INFO:gensim.topic_coherence.text_analysis:233 batches submitted to accumulate stats from 14912 documents (1331230 virtual)
# INFO:gensim.topic_coherence.text_analysis:234 batches submitted to accumulate stats from 14976 documents (1337161 virtual)
# INFO:gensim.topic_coherence.text_analysis:235 batches submitted to accumulate stats from 15040 documents (1342915 virtual)
# INFO:gensim.topic_coherence.text_analysis:236 batches submitted to accumulate stats from 15104 documents (1348437 virtual)
# INFO:gensim.topic_coherence.text_analysis:237 batches submitted to accumulate stats from 15168 documents (1354140 virtual)
# INFO:gensim.topic_coherence.text_analysis:238 batches submitted to accumulate stats from 15232 documents (1360196 virtual)
# INFO:gensim.topic_coherence.text_analysis:239 batches submitted to accumulate stats from 15296 documents (1366020 virtual)
# INFO:gensim.topic_coherence.text_analysis:240 batches submitted to accumulate stats from 15360 documents (1371930 virtual)
# INFO:gensim.topic_coherence.text_analysis:241 batches submitted to accumulate stats from 15424 documents (1377793 virtual)
# INFO:gensim.topic_coherence.text_analysis:242 batches submitted to accumulate stats from 15488 documents (1383691 virtual)
# INFO:gensim.topic_coherence.text_analysis:243 batches submitted to accumulate stats from 15552 documents (1389571 virtual)
# INFO:gensim.topic_coherence.text_analysis:244 batches submitted to accumulate stats from 15616 documents (1395273 virtual)
# INFO:gensim.topic_coherence.text_analysis:245 batches submitted to accumulate stats from 15680 documents (1401009 virtual)
# INFO:gensim.topic_coherence.text_analysis:246 batches submitted to accumulate stats from 15744 documents (1406543 virtual)
# INFO:gensim.topic_coherence.text_analysis:247 batches submitted to accumulate stats from 15808 documents (1412285 virtual)
# INFO:gensim.topic_coherence.text_analysis:248 batches submitted to accumulate stats from 15872 documents (1417971 virtual)
# INFO:gensim.topic_coherence.text_analysis:249 batches submitted to accumulate stats from 15936 documents (1423598 virtual)
# INFO:gensim.topic_coherence.text_analysis:250 batches submitted to accumulate stats from 16000 documents (1429266 virtual)
# INFO:gensim.topic_coherence.text_analysis:251 batches submitted to accumulate stats from 16064 documents (1434900 virtual)
# INFO:gensim.topic_coherence.text_analysis:252 batches submitted to accumulate stats from 16128 documents (1440600 virtual)
# INFO:gensim.topic_coherence.text_analysis:253 batches submitted to accumulate stats from 16192 documents (1446395 virtual)
# INFO:gensim.topic_coherence.text_analysis:254 batches submitted to accumulate stats from 16256 documents (1451920 virtual)
# INFO:gensim.topic_coherence.text_analysis:255 batches submitted to accumulate stats from 16320 documents (1457533 virtual)
# INFO:gensim.topic_coherence.text_analysis:256 batches submitted to accumulate stats from 16384 documents (1463259 virtual)
# INFO:gensim.topic_coherence.text_analysis:257 batches submitted to accumulate stats from 16448 documents (1468847 virtual)
# INFO:gensim.topic_coherence.text_analysis:258 batches submitted to accumulate stats from 16512 documents (1474212 virtual)
# INFO:gensim.topic_coherence.text_analysis:259 batches submitted to accumulate stats from 16576 documents (1479964 virtual)
# INFO:gensim.topic_coherence.text_analysis:260 batches submitted to accumulate stats from 16640 documents (1485411 virtual)
# INFO:gensim.topic_coherence.text_analysis:261 batches submitted to accumulate stats from 16704 documents (1491115 virtual)
# INFO:gensim.topic_coherence.text_analysis:262 batches submitted to accumulate stats from 16768 documents (1496747 virtual)
# INFO:gensim.topic_coherence.text_analysis:263 batches submitted to accumulate stats from 16832 documents (1502413 virtual)
# INFO:gensim.topic_coherence.text_analysis:264 batches submitted to accumulate stats from 16896 documents (1508045 virtual)
# INFO:gensim.topic_coherence.text_analysis:265 batches submitted to accumulate stats from 16960 documents (1513953 virtual)
# INFO:gensim.topic_coherence.text_analysis:266 batches submitted to accumulate stats from 17024 documents (1519740 virtual)
# INFO:gensim.topic_coherence.text_analysis:267 batches submitted to accumulate stats from 17088 documents (1525711 virtual)
# INFO:gensim.topic_coherence.text_analysis:268 batches submitted to accumulate stats from 17152 documents (1531342 virtual)
# INFO:gensim.topic_coherence.text_analysis:269 batches submitted to accumulate stats from 17216 documents (1537201 virtual)
# INFO:gensim.topic_coherence.text_analysis:270 batches submitted to accumulate stats from 17280 documents (1542672 virtual)
# INFO:gensim.topic_coherence.text_analysis:271 batches submitted to accumulate stats from 17344 documents (1548246 virtual)
# INFO:gensim.topic_coherence.text_analysis:272 batches submitted to accumulate stats from 17408 documents (1554197 virtual)
# INFO:gensim.topic_coherence.text_analysis:273 batches submitted to accumulate stats from 17472 documents (1559756 virtual)
# INFO:gensim.topic_coherence.text_analysis:274 batches submitted to accumulate stats from 17536 documents (1565550 virtual)
# INFO:gensim.topic_coherence.text_analysis:275 batches submitted to accumulate stats from 17600 documents (1571327 virtual)
# INFO:gensim.topic_coherence.text_analysis:276 batches submitted to accumulate stats from 17664 documents (1576918 virtual)
# INFO:gensim.topic_coherence.text_analysis:277 batches submitted to accumulate stats from 17728 documents (1582847 virtual)
# INFO:gensim.topic_coherence.text_analysis:278 batches submitted to accumulate stats from 17792 documents (1588777 virtual)
# INFO:gensim.topic_coherence.text_analysis:279 batches submitted to accumulate stats from 17856 documents (1594680 virtual)
# INFO:gensim.topic_coherence.text_analysis:280 batches submitted to accumulate stats from 17920 documents (1600423 virtual)
# INFO:gensim.topic_coherence.text_analysis:281 batches submitted to accumulate stats from 17984 documents (1606061 virtual)
# INFO:gensim.topic_coherence.text_analysis:282 batches submitted to accumulate stats from 18048 documents (1611861 virtual)
# INFO:gensim.topic_coherence.text_analysis:283 batches submitted to accumulate stats from 18112 documents (1617532 virtual)
# INFO:gensim.topic_coherence.text_analysis:284 batches submitted to accumulate stats from 18176 documents (1623273 virtual)
# INFO:gensim.topic_coherence.text_analysis:285 batches submitted to accumulate stats from 18240 documents (1629211 virtual)
# INFO:gensim.topic_coherence.text_analysis:286 batches submitted to accumulate stats from 18304 documents (1635085 virtual)
# INFO:gensim.topic_coherence.text_analysis:287 batches submitted to accumulate stats from 18368 documents (1640711 virtual)
# INFO:gensim.topic_coherence.text_analysis:288 batches submitted to accumulate stats from 18432 documents (1646574 virtual)
# INFO:gensim.topic_coherence.text_analysis:289 batches submitted to accumulate stats from 18496 documents (1652406 virtual)
# INFO:gensim.topic_coherence.text_analysis:290 batches submitted to accumulate stats from 18560 documents (1658325 virtual)
# INFO:gensim.topic_coherence.text_analysis:291 batches submitted to accumulate stats from 18624 documents (1664002 virtual)
# INFO:gensim.topic_coherence.text_analysis:292 batches submitted to accumulate stats from 18688 documents (1669471 virtual)
# INFO:gensim.topic_coherence.text_analysis:293 batches submitted to accumulate stats from 18752 documents (1675296 virtual)
# INFO:gensim.topic_coherence.text_analysis:294 batches submitted to accumulate stats from 18816 documents (1681134 virtual)
# INFO:gensim.topic_coherence.text_analysis:295 batches submitted to accumulate stats from 18880 documents (1686551 virtual)
# INFO:gensim.topic_coherence.text_analysis:296 batches submitted to accumulate stats from 18944 documents (1692266 virtual)
# INFO:gensim.topic_coherence.text_analysis:297 batches submitted to accumulate stats from 19008 documents (1698048 virtual)
# INFO:gensim.topic_coherence.text_analysis:298 batches submitted to accumulate stats from 19072 documents (1703676 virtual)
# INFO:gensim.topic_coherence.text_analysis:299 batches submitted to accumulate stats from 19136 documents (1709153 virtual)
# INFO:gensim.topic_coherence.text_analysis:300 batches submitted to accumulate stats from 19200 documents (1714815 virtual)
# INFO:gensim.topic_coherence.text_analysis:301 batches submitted to accumulate stats from 19264 documents (1720509 virtual)
# INFO:gensim.topic_coherence.text_analysis:302 batches submitted to accumulate stats from 19328 documents (1726001 virtual)
# INFO:gensim.topic_coherence.text_analysis:303 batches submitted to accumulate stats from 19392 documents (1731620 virtual)
# INFO:gensim.topic_coherence.text_analysis:304 batches submitted to accumulate stats from 19456 documents (1737660 virtual)
# INFO:gensim.topic_coherence.text_analysis:305 batches submitted to accumulate stats from 19520 documents (1743269 virtual)
# INFO:gensim.topic_coherence.text_analysis:306 batches submitted to accumulate stats from 19584 documents (1748782 virtual)
# INFO:gensim.topic_coherence.text_analysis:307 batches submitted to accumulate stats from 19648 documents (1754539 virtual)
# INFO:gensim.topic_coherence.text_analysis:308 batches submitted to accumulate stats from 19712 documents (1760323 virtual)
# INFO:gensim.topic_coherence.text_analysis:309 batches submitted to accumulate stats from 19776 documents (1766086 virtual)
# INFO:gensim.topic_coherence.text_analysis:310 batches submitted to accumulate stats from 19840 documents (1772029 virtual)
# INFO:gensim.topic_coherence.text_analysis:311 batches submitted to accumulate stats from 19904 documents (1777651 virtual)
# INFO:gensim.topic_coherence.text_analysis:312 batches submitted to accumulate stats from 19968 documents (1783232 virtual)
# INFO:gensim.topic_coherence.text_analysis:313 batches submitted to accumulate stats from 20032 documents (1788901 virtual)
# INFO:gensim.topic_coherence.text_analysis:314 batches submitted to accumulate stats from 20096 documents (1794654 virtual)
# INFO:gensim.topic_coherence.text_analysis:315 batches submitted to accumulate stats from 20160 documents (1800315 virtual)
# INFO:gensim.topic_coherence.text_analysis:316 batches submitted to accumulate stats from 20224 documents (1805693 virtual)
# INFO:gensim.topic_coherence.text_analysis:317 batches submitted to accumulate stats from 20288 documents (1811470 virtual)
# INFO:gensim.topic_coherence.text_analysis:318 batches submitted to accumulate stats from 20352 documents (1817149 virtual)
# INFO:gensim.topic_coherence.text_analysis:319 batches submitted to accumulate stats from 20416 documents (1822597 virtual)
# INFO:gensim.topic_coherence.text_analysis:320 batches submitted to accumulate stats from 20480 documents (1828503 virtual)
# INFO:gensim.topic_coherence.text_analysis:321 batches submitted to accumulate stats from 20544 documents (1834283 virtual)
# INFO:gensim.topic_coherence.text_analysis:322 batches submitted to accumulate stats from 20608 documents (1839955 virtual)
# INFO:gensim.topic_coherence.text_analysis:323 batches submitted to accumulate stats from 20672 documents (1845565 virtual)
# INFO:gensim.topic_coherence.text_analysis:324 batches submitted to accumulate stats from 20736 documents (1851158 virtual)
# INFO:gensim.topic_coherence.text_analysis:325 batches submitted to accumulate stats from 20800 documents (1856978 virtual)
# INFO:gensim.topic_coherence.text_analysis:326 batches submitted to accumulate stats from 20864 documents (1862855 virtual)
# INFO:gensim.topic_coherence.text_analysis:327 batches submitted to accumulate stats from 20928 documents (1868622 virtual)
# INFO:gensim.topic_coherence.text_analysis:328 batches submitted to accumulate stats from 20992 documents (1874231 virtual)
# INFO:gensim.topic_coherence.text_analysis:329 batches submitted to accumulate stats from 21056 documents (1879937 virtual)
# INFO:gensim.topic_coherence.text_analysis:330 batches submitted to accumulate stats from 21120 documents (1885645 virtual)
# INFO:gensim.topic_coherence.text_analysis:331 batches submitted to accumulate stats from 21184 documents (1891389 virtual)
# INFO:gensim.topic_coherence.text_analysis:332 batches submitted to accumulate stats from 21248 documents (1897001 virtual)
# INFO:gensim.topic_coherence.text_analysis:333 batches submitted to accumulate stats from 21312 documents (1902844 virtual)
# INFO:gensim.topic_coherence.text_analysis:334 batches submitted to accumulate stats from 21376 documents (1908102 virtual)
# INFO:gensim.topic_coherence.text_analysis:335 batches submitted to accumulate stats from 21440 documents (1913992 virtual)
# INFO:gensim.topic_coherence.text_analysis:336 batches submitted to accumulate stats from 21504 documents (1919565 virtual)
# INFO:gensim.topic_coherence.text_analysis:337 batches submitted to accumulate stats from 21568 documents (1925360 virtual)
# INFO:gensim.topic_coherence.text_analysis:338 batches submitted to accumulate stats from 21632 documents (1930955 virtual)
# INFO:gensim.topic_coherence.text_analysis:339 batches submitted to accumulate stats from 21696 documents (1936364 virtual)
# INFO:gensim.topic_coherence.text_analysis:340 batches submitted to accumulate stats from 21760 documents (1942002 virtual)
# INFO:gensim.topic_coherence.text_analysis:341 batches submitted to accumulate stats from 21824 documents (1947514 virtual)
# INFO:gensim.topic_coherence.text_analysis:342 batches submitted to accumulate stats from 21888 documents (1952930 virtual)
# INFO:gensim.topic_coherence.text_analysis:343 batches submitted to accumulate stats from 21952 documents (1958619 virtual)
# INFO:gensim.topic_coherence.text_analysis:344 batches submitted to accumulate stats from 22016 documents (1964268 virtual)
# INFO:gensim.topic_coherence.text_analysis:345 batches submitted to accumulate stats from 22080 documents (1970140 virtual)
# INFO:gensim.topic_coherence.text_analysis:346 batches submitted to accumulate stats from 22144 documents (1976027 virtual)
# INFO:gensim.topic_coherence.text_analysis:347 batches submitted to accumulate stats from 22208 documents (1981539 virtual)
# INFO:gensim.topic_coherence.text_analysis:348 batches submitted to accumulate stats from 22272 documents (1987327 virtual)
# INFO:gensim.topic_coherence.text_analysis:349 batches submitted to accumulate stats from 22336 documents (1992856 virtual)
# INFO:gensim.topic_coherence.text_analysis:350 batches submitted to accumulate stats from 22400 documents (1998525 virtual)
# INFO:gensim.topic_coherence.text_analysis:351 batches submitted to accumulate stats from 22464 documents (2004186 virtual)
# INFO:gensim.topic_coherence.text_analysis:352 batches submitted to accumulate stats from 22528 documents (2009902 virtual)
# INFO:gensim.topic_coherence.text_analysis:353 batches submitted to accumulate stats from 22592 documents (2015656 virtual)
# INFO:gensim.topic_coherence.text_analysis:354 batches submitted to accumulate stats from 22656 documents (2021074 virtual)
# INFO:gensim.topic_coherence.text_analysis:355 batches submitted to accumulate stats from 22720 documents (2026778 virtual)
# INFO:gensim.topic_coherence.text_analysis:356 batches submitted to accumulate stats from 22784 documents (2032639 virtual)
# INFO:gensim.topic_coherence.text_analysis:357 batches submitted to accumulate stats from 22848 documents (2038241 virtual)
# INFO:gensim.topic_coherence.text_analysis:358 batches submitted to accumulate stats from 22912 documents (2043942 virtual)
# INFO:gensim.topic_coherence.text_analysis:359 batches submitted to accumulate stats from 22976 documents (2049616 virtual)
# INFO:gensim.topic_coherence.text_analysis:360 batches submitted to accumulate stats from 23040 documents (2055238 virtual)
# INFO:gensim.topic_coherence.text_analysis:361 batches submitted to accumulate stats from 23104 documents (2061286 virtual)
# INFO:gensim.topic_coherence.text_analysis:362 batches submitted to accumulate stats from 23168 documents (2067134 virtual)
# INFO:gensim.topic_coherence.text_analysis:363 batches submitted to accumulate stats from 23232 documents (2072904 virtual)
# INFO:gensim.topic_coherence.text_analysis:364 batches submitted to accumulate stats from 23296 documents (2078698 virtual)
# INFO:gensim.topic_coherence.text_analysis:365 batches submitted to accumulate stats from 23360 documents (2084523 virtual)
# INFO:gensim.topic_coherence.text_analysis:366 batches submitted to accumulate stats from 23424 documents (2090557 virtual)
# ...
# INFO:gensim.topic_coherence.text_analysis:617 batches submitted to accumulate stats from 39488 documents (3521354 virtual)
# INFO:gensim.topic_coherence.text_analysis:618 batches submitted to accumulate stats from 39552 documents (3527124 virtual)
# INFO:gensim.topic_coherence.text_analysis:619 batches submitted to accumulate stats from 39616 documents (3532893 virtual)
# INFO:gensim.topic_coherence.text_analysis:620 batches submitted to accumulate stats from 39680 documents (3538553 virtual)
# INFO:gensim.topic_coherence.text_analysis:621 batches submitted to accumulate stats from 39744 documents (3544234 virtual)
# INFO:gensim.topic_coherence.text_analysis:622 batches submitted to accumulate stats from 39808 documents (3549812 virtual)
# INFO:gensim.topic_coherence.text_analysis:623 batches submitted to accumulate stats from 39872 documents (3555431 virtual)
# INFO:gensim.topic_coherence.text_analysis:624 batches submitted to accumulate stats from 39936 documents (3561215 virtual)
# INFO:gensim.topic_coherence.text_analysis:625 batches submitted to accumulate stats from 40000 documents (3567207 virtual)
# INFO:gensim.topic_coherence.text_analysis:626 batches submitted to accumulate stats from 40064 documents (3572817 virtual)
# INFO:gensim.topic_coherence.text_analysis:627 batches submitted to accumulate stats from 40128 documents (3578581 virtual)
# INFO:gensim.topic_coherence.text_analysis:628 batches submitted to accumulate stats from 40192 documents (3584218 virtual)
# INFO:gensim.topic_coherence.text_analysis:629 batches submitted to accumulate stats from 40256 documents (3589837 virtual)
# INFO:gensim.topic_coherence.text_analysis:630 batches submitted to accumulate stats from 40320 documents (3595691 virtual)
# INFO:gensim.topic_coherence.text_analysis:631 batches submitted to accumulate stats from 40384 documents (3601378 virtual)
# INFO:gensim.topic_coherence.text_analysis:632 batches submitted to accumulate stats from 40448 documents (3607056 virtual)
# INFO:gensim.topic_coherence.text_analysis:633 batches submitted to accumulate stats from 40512 documents (3612958 virtual)
# INFO:gensim.topic_coherence.text_analysis:634 batches submitted to accumulate stats from 40576 documents (3618806 virtual)
# INFO:gensim.topic_coherence.text_analysis:635 batches submitted to accumulate stats from 40640 documents (3624605 virtual)
# INFO:gensim.topic_coherence.text_analysis:636 batches submitted to accumulate stats from 40704 documents (3629883 virtual)
# INFO:gensim.topic_coherence.text_analysis:637 batches submitted to accumulate stats from 40768 documents (3635632 virtual)
# INFO:gensim.topic_coherence.text_analysis:638 batches submitted to accumulate stats from 40832 documents (3641604 virtual)
# INFO:gensim.topic_coherence.text_analysis:639 batches submitted to accumulate stats from 40896 documents (3647262 virtual)
# INFO:gensim.topic_coherence.text_analysis:640 batches submitted to accumulate stats from 40960 documents (3652871 virtual)
# INFO:gensim.topic_coherence.text_analysis:641 batches submitted to accumulate stats from 41024 documents (3658572 virtual)
# INFO:gensim.topic_coherence.text_analysis:642 batches submitted to accumulate stats from 41088 documents (3664069 virtual)
# INFO:gensim.topic_coherence.text_analysis:643 batches submitted to accumulate stats from 41152 documents (3669890 virtual)
# INFO:gensim.topic_coherence.text_analysis:644 batches submitted to accumulate stats from 41216 documents (3675314 virtual)
# INFO:gensim.topic_coherence.text_analysis:645 batches submitted to accumulate stats from 41280 documents (3681197 virtual)
# INFO:gensim.topic_coherence.text_analysis:646 batches submitted to accumulate stats from 41344 documents (3686964 virtual)
# INFO:gensim.topic_coherence.text_analysis:647 batches submitted to accumulate stats from 41408 documents (3692541 virtual)
# INFO:gensim.topic_coherence.text_analysis:648 batches submitted to accumulate stats from 41472 documents (3698278 virtual)
# INFO:gensim.topic_coherence.text_analysis:649 batches submitted to accumulate stats from 41536 documents (3703905 virtual)
# INFO:gensim.topic_coherence.text_analysis:650 batches submitted to accumulate stats from 41600 documents (3709882 virtual)
# INFO:gensim.topic_coherence.text_analysis:651 batches submitted to accumulate stats from 41664 documents (3715441 virtual)
# INFO:gensim.topic_coherence.text_analysis:652 batches submitted to accumulate stats from 41728 documents (3721222 virtual)
# INFO:gensim.topic_coherence.text_analysis:653 batches submitted to accumulate stats from 41792 documents (3727221 virtual)
# INFO:gensim.topic_coherence.text_analysis:654 batches submitted to accumulate stats from 41856 documents (3732729 virtual)
# INFO:gensim.topic_coherence.text_analysis:655 batches submitted to accumulate stats from 41920 documents (3737981 virtual)
# INFO:gensim.topic_coherence.text_analysis:656 batches submitted to accumulate stats from 41984 documents (3743459 virtual)
# INFO:gensim.topic_coherence.text_analysis:657 batches submitted to accumulate stats from 42048 documents (3749165 virtual)
# INFO:gensim.topic_coherence.text_analysis:658 batches submitted to accumulate stats from 42112 documents (3754676 virtual)
# INFO:gensim.topic_coherence.text_analysis:659 batches submitted to accumulate stats from 42176 documents (3760251 virtual)
# INFO:gensim.topic_coherence.text_analysis:660 batches submitted to accumulate stats from 42240 documents (3766146 virtual)
# INFO:gensim.topic_coherence.text_analysis:661 batches submitted to accumulate stats from 42304 documents (3771663 virtual)
# INFO:gensim.topic_coherence.text_analysis:662 batches submitted to accumulate stats from 42368 documents (3777035 virtual)
# INFO:gensim.topic_coherence.text_analysis:663 batches submitted to accumulate stats from 42432 documents (3782953 virtual)
# INFO:gensim.topic_coherence.text_analysis:664 batches submitted to accumulate stats from 42496 documents (3788645 virtual)
# INFO:gensim.topic_coherence.text_analysis:665 batches submitted to accumulate stats from 42560 documents (3794088 virtual)
# INFO:gensim.topic_coherence.text_analysis:666 batches submitted to accumulate stats from 42624 documents (3799727 virtual)
# INFO:gensim.topic_coherence.text_analysis:667 batches submitted to accumulate stats from 42688 documents (3805403 virtual)
# INFO:gensim.topic_coherence.text_analysis:668 batches submitted to accumulate stats from 42752 documents (3811365 virtual)
# INFO:gensim.topic_coherence.text_analysis:669 batches submitted to accumulate stats from 42816 documents (3816814 virtual)
# INFO:gensim.topic_coherence.text_analysis:670 batches submitted to accumulate stats from 42880 documents (3822662 virtual)
# INFO:gensim.topic_coherence.text_analysis:671 batches submitted to accumulate stats from 42944 documents (3828207 virtual)
# INFO:gensim.topic_coherence.text_analysis:672 batches submitted to accumulate stats from 43008 documents (3833825 virtual)
# INFO:gensim.topic_coherence.text_analysis:673 batches submitted to accumulate stats from 43072 documents (3839955 virtual)
# INFO:gensim.topic_coherence.text_analysis:674 batches submitted to accumulate stats from 43136 documents (3845441 virtual)
# INFO:gensim.topic_coherence.text_analysis:675 batches submitted to accumulate stats from 43200 documents (3850866 virtual)
# INFO:gensim.topic_coherence.text_analysis:676 batches submitted to accumulate stats from 43264 documents (3856743 virtual)
# INFO:gensim.topic_coherence.text_analysis:677 batches submitted to accumulate stats from 43328 documents (3862441 virtual)
# INFO:gensim.topic_coherence.text_analysis:678 batches submitted to accumulate stats from 43392 documents (3868084 virtual)
# INFO:gensim.topic_coherence.text_analysis:679 batches submitted to accumulate stats from 43456 documents (3873823 virtual)
# INFO:gensim.topic_coherence.text_analysis:680 batches submitted to accumulate stats from 43520 documents (3879636 virtual)
# INFO:gensim.topic_coherence.text_analysis:681 batches submitted to accumulate stats from 43584 documents (3885186 virtual)
# INFO:gensim.topic_coherence.text_analysis:682 batches submitted to accumulate stats from 43648 documents (3890894 virtual)
# INFO:gensim.topic_coherence.text_analysis:683 batches submitted to accumulate stats from 43712 documents (3896358 virtual)
# INFO:gensim.topic_coherence.text_analysis:684 batches submitted to accumulate stats from 43776 documents (3902068 virtual)
# INFO:gensim.topic_coherence.text_analysis:685 batches submitted to accumulate stats from 43840 documents (3907752 virtual)
# INFO:gensim.topic_coherence.text_analysis:686 batches submitted to accumulate stats from 43904 documents (3913535 virtual)
# INFO:gensim.topic_coherence.text_analysis:687 batches submitted to accumulate stats from 43968 documents (3919253 virtual)
# INFO:gensim.topic_coherence.text_analysis:688 batches submitted to accumulate stats from 44032 documents (3924772 virtual)
# INFO:gensim.topic_coherence.text_analysis:689 batches submitted to accumulate stats from 44096 documents (3930751 virtual)
# INFO:gensim.topic_coherence.text_analysis:690 batches submitted to accumulate stats from 44160 documents (3936536 virtual)
# INFO:gensim.topic_coherence.text_analysis:691 batches submitted to accumulate stats from 44224 documents (3942425 virtual)
# INFO:gensim.topic_coherence.text_analysis:692 batches submitted to accumulate stats from 44288 documents (3948051 virtual)
# INFO:gensim.topic_coherence.text_analysis:693 batches submitted to accumulate stats from 44352 documents (3953693 virtual)
# INFO:gensim.topic_coherence.text_analysis:694 batches submitted to accumulate stats from 44416 documents (3959268 virtual)
# INFO:gensim.topic_coherence.text_analysis:695 batches submitted to accumulate stats from 44480 documents (3964874 virtual)
# INFO:gensim.topic_coherence.text_analysis:696 batches submitted to accumulate stats from 44544 documents (3970481 virtual)
# INFO:gensim.topic_coherence.text_analysis:697 batches submitted to accumulate stats from 44608 documents (3976161 virtual)
# INFO:gensim.topic_coherence.text_analysis:698 batches submitted to accumulate stats from 44672 documents (3981738 virtual)
# INFO:gensim.topic_coherence.text_analysis:699 batches submitted to accumulate stats from 44736 documents (3987548 virtual)
# INFO:gensim.topic_coherence.text_analysis:700 batches submitted to accumulate stats from 44800 documents (3993302 virtual)
# INFO:gensim.topic_coherence.text_analysis:701 batches submitted to accumulate stats from 44864 documents (3999061 virtual)
# INFO:gensim.topic_coherence.text_analysis:702 batches submitted to accumulate stats from 44928 documents (4004785 virtual)
# INFO:gensim.topic_coherence.text_analysis:703 batches submitted to accumulate stats from 44992 documents (4010736 virtual)
# INFO:gensim.topic_coherence.text_analysis:704 batches submitted to accumulate stats from 45056 documents (4016357 virtual)
# INFO:gensim.topic_coherence.text_analysis:705 batches submitted to accumulate stats from 45120 documents (4022272 virtual)
# INFO:gensim.topic_coherence.text_analysis:706 batches submitted to accumulate stats from 45184 documents (4027795 virtual)
# INFO:gensim.topic_coherence.text_analysis:707 batches submitted to accumulate stats from 45248 documents (4033538 virtual)
# INFO:gensim.topic_coherence.text_analysis:708 batches submitted to accumulate stats from 45312 documents (4039393 virtual)
# INFO:gensim.topic_coherence.text_analysis:709 batches submitted to accumulate stats from 45376 documents (4044825 virtual)
# INFO:gensim.topic_coherence.text_analysis:710 batches submitted to accumulate stats from 45440 documents (4050482 virtual)
# INFO:gensim.topic_coherence.text_analysis:711 batches submitted to accumulate stats from 45504 documents (4055987 virtual)
# INFO:gensim.topic_coherence.text_analysis:712 batches submitted to accumulate stats from 45568 documents (4061800 virtual)
# INFO:gensim.topic_coherence.text_analysis:713 batches submitted to accumulate stats from 45632 documents (4067468 virtual)
# INFO:gensim.topic_coherence.text_analysis:714 batches submitted to accumulate stats from 45696 documents (4073146 virtual)
# INFO:gensim.topic_coherence.text_analysis:715 batches submitted to accumulate stats from 45760 documents (4078735 virtual)
# INFO:gensim.topic_coherence.text_analysis:716 batches submitted to accumulate stats from 45824 documents (4084467 virtual)
# INFO:gensim.topic_coherence.text_analysis:717 batches submitted to accumulate stats from 45888 documents (4085709 virtual)
# INFO:gensim.topic_coherence.text_analysis:7 accumulators retrieved from output queue
# INFO:gensim.topic_coherence.text_analysis:accumulated word occurrence stats for 4085713 virtual documents
# INFO:TMmodel:[0.6242889979163306, 0.7640702606368759, 0.505968138424412, 0.4627337588833527, 0.5705773780236945, 0.08622941653910293, 0.122837760362176, 0.0071657172901805, -0.2113388021717534, 0.06227918504068066]
# /Users/lbartolome/Documents/GitHub/UserInLoopHTM/.venv/lib/python3.8/site-packages/pyLDAvis/_prepare.py:246: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   default_term_info = default_term_info.sort_values(
# INFO:TMmodel:-- -- Topic model variables were computed and saved to file
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /Users/lbartolome/Documents/GitHub/UserInLoopHTM/notebooks/ctm_dropout_analysis.ipynb Cell 7 in <module>
# ----> <a href='vscode-notebook-cell:/Users/lbartolome/Documents/GitHub/UserInLoopHTM/notebooks/ctm_dropout_analysis.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> train_automatic(path_corpus="/Users/lbartolome/Documents/GitHub/UserInLoopHTM/data/CORDIS/corpus.parquet", path_script="/Users/lbartolome/Documents/GitHub/UserInLoopHTM")
#
# /Users/lbartolome/Documents/GitHub/UserInLoopHTM/notebooks/ctm_dropout_analysis.ipynb Cell 7 in train_automatic(path_corpus, path_script)
#      <a href='vscode-notebook-cell:/Users/lbartolome/Documents/GitHub/UserInLoopHTM/notebooks/ctm_dropout_analysis.ipynb#W6sZmlsZQ%3D%3D?line=28'>29</a> print(cmd)
#      <a href='vscode-notebook-cell:/Users/lbartolome/Documents/GitHub/UserInLoopHTM/notebooks/ctm_dropout_analysis.ipynb#W6sZmlsZQ%3D%3D?line=30'>31</a> print(f'-- -- Running command {cmd}')
# ---> <a href='vscode-notebook-cell:/Users/lbartolome/Documents/GitHub/UserInLoopHTM/notebooks/ctm_dropout_analysis.ipynb#W6sZmlsZQ%3D%3D?line=31'>32</a> output = check_output(args=cmd, shell=True)
#      <a href='vscode-notebook-cell:/Users/lbartolome/Documents/GitHub/UserInLoopHTM/notebooks/ctm_dropout_analysis.ipynb#W6sZmlsZQ%3D%3D?line=32'>33</a> t_end = time.perf_counter()
#      <a href='vscode-notebook-cell:/Users/lbartolome/Documents/GitHub/UserInLoopHTM/notebooks/ctm_dropout_analysis.ipynb#W6sZmlsZQ%3D%3D?line=34'>35</a> t_total = t_end - t_start
#
# File /opt/homebrew/Cellar/python@3.8/3.8.16/Frameworks/Python.framework/Versions/3.8/lib/python3.8/subprocess.py:415, in check_output(timeout, *popenargs, **kwargs)
#     412         empty = b''
#     413     kwargs['input'] = empty
# --> 415 return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     416            **kwargs).stdout
#
# File /opt/homebrew/Cellar/python@3.8/3.8.16/Frameworks/Python.framework/Versions/3.8/lib/python3.8/subprocess.py:516, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     514     retcode = process.poll()
#     515     if check and retcode:
# --> 516         raise CalledProcessError(retcode, process.args,
#     517                                  output=stdout, stderr=stderr)
#     518 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command 'python /Users/lbartolome/Documents/GitHub/UserInLoopHTM/src/topicmodeling/topicmodeling.py --train --config /Users/lbartolome/Documents/GitHub/UserInLoopHTM/data/CORDIS/trainconfig.json' died with <Signals.SIGSEGV: 11>.

# %%
path_model = \
    pathlib.Path("/Users/lbartolome/Documents/GitHub/UserInLoopHTM/data/CORDIS/TMmodel")

# %%
thetas = sparse.load_npz(path_model.joinpath("thetas.npz"))
# ndocs x ntopics: (45837, ntopics)
thetas_dense = thetas.todense()

# %%
def sum_up_to(vector, max_sum):
    x = np.array(list(map(np.int_, vector*max_sum))).ravel()
    pos_idx = list(np.where(x != 0)[0])
    while np.sum(x) != max_sum:
        idx = random.choice(pos_idx)
        x[idx] += 1
    return x

def get_str_rpr(vector, max_sum):
    vector = sum_up_to(vector, max_sum)
    rpr = ""
    for idx,val in enumerate(vector):
        rpr += "t" + str(idx) + "|" + str(val) + " "
    rpr = rpr.rstrip() 
    return rpr

# %%
corpus_txt = [line.rsplit(' 0 ')[1].strip() for line in open(
    pathlib.Path("/Users/lbartolome/Documents/GitHub/UserInLoopHTM/data/CORDIS/modelFiles/corpus.txt"), encoding="utf-8").readlines()]
print(len(corpus_txt))
doc_tpc_rpr = [get_str_rpr(thetas_dense[row,:], 1000) for row in range(len(thetas_dense))]

df = pd.DataFrame(list(zip(corpus_txt,doc_tpc_rpr)),
               columns =['lemmas', 'doc-tpc'])
df
# Out:
# 45837
#                                                   lemmas  \
# 0      discovery pleasure change italy long west repr...
# 1      spectroscopic computing investigation chromium...
# 2      enterprise_europe targeting innovation impleme...
# 3      network observatories research_infrastructures...
# 4      dynamical large_number partial_differential ph...
# ...                                                  ...
# 45832  causal relations genetic environment interacti...
# 45833  theranostic nanomedicines oncology combinatori...
# 45834  tame legal politic accountability post_crisis ...
# 45835  mathematic methods financial risk management p...
# 45836  roadmap enabling vision strategy information_a...
#
#                                   doc-tpc
# 0          t0|808 t1|66 t2|59 t3|39 t4|28
# 1      t0|227 t1|127 t2|150 t3|116 t4|380
# 2         t0|81 t1|534 t2|58 t3|251 t4|76
# 3        t0|242 t1|437 t2|142 t3|90 t4|89
# 4        t0|532 t1|56 t2|208 t3|34 t4|170
# ...                                   ...
# 45832   t0|244 t1|353 t2|243 t3|58 t4|102
# 45833    t0|68 t1|108 t2|646 t3|66 t4|112
# 45834     t0|378 t1|413 t2|96 t3|52 t4|61
# 45835   t0|464 t1|146 t2|74 t3|159 t4|157
# 45836     t0|63 t1|715 t2|43 t3|132 t4|47
#
# [45837 rows x 2 columns]

# %%
df, vocab_id2w = TMmodel(path_model).to_dataframe()
df['cohr_cv'] = df['topic_coherence'].apply(lambda x: x[0:ntopics])
df['cohr_npmi'] = df['topic_coherence'].apply(lambda x: x[ntopics:])
df.drop(columns=['topic_coherence'], inplace=True)
df = df.apply(pd.Series.explode)
df.reset_index(drop=True)
df["id"] = [f"t{i}" for i in range(len(df))]
df.set_index("id", inplace=True)
df.sort_values(by=['alphas'],ascending=False)
# Out:
# INFO:TMmodel:-- -- -- Topic model object (TMmodel) successfully created
#                                                 betas    alphas topic_entropy
# id
# t0  [5.199836e-05, 4.97296e-05, 4.988181e-05, 4.98...  0.211105      0.999898  \
# t1  [4.9700728e-05, 5.1815525e-05, 5.125947e-05, 5...  0.208491      0.999909
# t2  [5.0690152e-05, 5.0512714e-05, 4.9998544e-05, ...  0.199761       0.99992
# t3  [5.0266062e-05, 5.0365707e-05, 4.97803e-05, 5....  0.193079      0.999947
# t4  [5.001027e-05, 5.009509e-05, 5.085136e-05, 5.0...  0.187566      0.999937
#
#    ndocs_active                                   tpc_descriptions tpc_labels
# id
# t0        45837  tradition, mathematic, scholar, history, croat...         NA  \
# t1        45837  stakeholders, policy, network, implementation,...         NA
# t2        45837  identify, drug, associate, therapy, genome, ge...         NA
# t3        45837  market, reduce, battery, production, safe, equ...         NA
# t4        45837  spin, electronic, catalysis, magnetic, frequen...         NA
#
#      cohr_cv cohr_npmi
# id
# t0  0.393015 -0.174302
# t1  0.660844  0.084611
# t2  0.761429  0.111183
# t3  0.617074  0.066994
# t4  0.668901   0.09535

# %%
df.tpc_descriptions.values.tolist()
# Out:
# ['tradition, mathematic, scholar, history, croatian, relation, notion, dig, draw, contemporary, neglect, carbohydrate_chemistry, catapult, selection_committee, researcher_night',
#  'stakeholders, policy, network, implementation, support, country, innovation, impact, regional, governance, good_practice, facilitate, organisation, management, action',
#  'identify, drug, associate, therapy, genome, genetic, mediate, tissue, stem_cell, cancer, biology, regulation, disease, tumor, mouse',
#  'market, reduce, battery, production, safe, equipment, company, vehicle, operational, pricing, manufacture, industry, water, demonstration, product',
#  'spin, electronic, catalysis, magnetic, frequency, quantum, semiconductor, nanoscale, computing, interface, chemistry, information_processing, surface, coupling, nanostructure']
