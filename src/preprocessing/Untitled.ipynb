# %%
import pandas as pd
import pathlib

# %%
df = pd.read_parquet(pathlib.Path("/export/usuarios_ml4ds/lbartolome/Datasets/CORDIS/embeddings/parquet_embeddings_part_0.parquet"))

# %%
df
# Out:
#        projectID                                          objective  \
# 0         115843  The current Ebola Virus Disease (EVD) outbreak...
# 1         115910  Pertussis vaccines have been very successful i...
# 2         200978  The complex functions of a living cell are car...
# 3         206734  In the context of unprecedented anthropogenic ...
# 4         212337  The strategic objective of the project is to i...
# ...          ...                                                ...
# 61162  101027955  Betalactams (BL) are the most widely used anti...
# 61163  101028945  Cancer patients are of high risk to develop se...
# 61164  101032880  Single particle plasmonic nanospectroscopy is ...
# 61165  101034290  Addressing the increased need for innovative s...
# 61166  101038097  Dynamic technological development and the grow...
#
#                                                    title langue  \
# 0      Ebola Virus: Modern Approaches for developing ...     en
# ...
